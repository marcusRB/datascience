# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FormatStrFormatter
import datetime


# %matplotlib inline
plt.rcParams['figure.figsize'] = (16.0, 12.0)

# %%
import os
os.getcwd()
# Out:
# '/home/marcusrb/Documents/github/datascience/cabify2010'

# %%
dataset = "Cabify_2010.xlsx"
cabify2010 = pd.read_excel(dataset)

# %%
cabify2010.head(n=10)
# Out:
#                          journey_id                           user_id  \
# 0  23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1  dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2  dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3  dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4  85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
# 5  2254715f0f569e3173ec61f16cbb8341  56772d544fdfa589a020a1ff894a86f7
# 6  12432d83b49393bf25164673212b8295  56772d544fdfa589a020a1ff894a86f7
# 7  2e51db3a8a77aa594aa686ff19fe6036  56772d544fdfa589a020a1ff894a86f7
# 8  0234eb5f7e99d581c72052f0a868289c  0234eb5f7e99d581c72052f0a869293a
# 9  9448070ece760ea5386e5d4822121a6c  dd23cf0ef33ae44e0c0b4c756e1fe4e8
#
#                           driver_id                           taxi_id  \
# 0  583949a89a9ee17d19e3ca4f137b6b4c  b12f4f09c783e29fe0d0ea624530db56
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4  d665fb9f75ef5d9cd0fd89479380ba78  0accdd3aa5a322f4129fa20b53278c69
# 5  baacf396f773709519bbde35a5eab861  baacf396f773709519bbde35a585d91b
# 6  e1332f68e81526e498e4d845233a6d7d  e1332f68e81526e498e4d845235baf80
# 7  d665fb9f75ef5d9cd0fd89479380ba78  0accdd3aa5a322f4129fa20b53278c69
# 8  d04f1a596fe4a582f48e6eb2f9e8f617  d04f1a596fe4a582f48e6eb2f9e8cceb
# 9  406921adcca37705ef527b4246c0cfea  406921adcca37705ef527b4246c10d2c
#
#         icon start_type            start_at  start_lat  start_lon  \
# 0  executive       asap 2010-11-16 16:44:52 -12.139835 -77.023560
# 1  executive       asap 2010-06-01 00:34:38 -12.138748 -76.995361
# 2  executive       asap 2010-05-31 05:01:24 -12.124531 -77.027802
# 3  executive       asap 2010-06-01 00:29:30 -12.138851 -76.995300
# 4  executive   reserved 2010-09-11 23:55:00 -12.089954 -76.926270
# 5  executive   reserved 2010-08-10 13:00:00 -12.022419 -77.106506
# 6  executive   reserved 2010-08-08 12:10:00 -12.089958 -76.926208
# 7  executive       asap 2010-05-16 03:58:59 -12.113472 -77.043854
# 8  executive       asap 2010-07-09 05:56:01 -12.110683 -77.002121
# 9  executive       asap 2010-11-22 23:42:54 -12.089696 -77.035749
#
#                end_at  ...  price_distance  price_duration distance  duration  \
# 0 2010-11-16 17:29:57  ...          3626.0           195.0  11331.0     234.0
# 1 2010-06-01 00:37:39  ...             NaN             NaN      0.0       0.0
# 2 2010-05-31 05:04:34  ...             NaN             NaN      0.0       0.0
# 3 2010-06-01 00:32:35  ...             NaN             NaN      0.0       0.0
# 4 2010-09-12 01:07:02  ...          7665.0           562.0  30270.0     715.0
# 5 2010-08-10 14:26:51  ...          7393.0          1001.0  29080.0    1201.0
# 6 2010-08-08 12:48:02  ...          7112.0             0.0  27230.0       0.0
# 7 2010-05-16 04:40:35  ...          5519.0           193.0  17247.0     232.0
# 8 2010-07-09 06:37:40  ...          4602.0            78.0  14380.0      94.0
# 9 2010-11-23 00:53:15  ...          2580.0           565.0   8064.0     676.0
#
#      cost cost_distance cost_duration   source  driver_score  rider_score
# 0     0.0           0.0           0.0   iPhone           5.0          5.0
# 1     0.0           NaN           NaN   iPhone           NaN          NaN
# 2     0.0           NaN           NaN   iPhone           NaN          NaN
# 3     0.0           NaN           NaN   iPhone           NaN          NaN
# 4  6173.0        5756.0         417.0   iPhone           4.0          5.0
# 5  5875.0        5175.0         700.0   iPhone           NaN          4.0
# 6  5340.0        5340.0           0.0   iPhone           5.0          5.0
# 7  4282.0        4139.0         143.0   iPhone           5.0          5.0
# 8  3509.0        3451.0          58.0  Android           0.0          4.0
# 9  2353.0        1935.0         418.0  Android           5.0          5.0
#
# [10 rows x 28 columns]

# %%
cabify2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23111 entries, 0 to 23110
# Data columns (total 28 columns):
# journey_id          23111 non-null object
# user_id             23111 non-null object
# driver_id           19726 non-null object
# taxi_id             19726 non-null object
# icon                23111 non-null object
# start_type          23111 non-null object
# start_at            23111 non-null datetime64[ns]
# start_lat           23111 non-null float64
# start_lon           23111 non-null float64
# end_at              22835 non-null datetime64[ns]
# end_lat             23111 non-null float64
# end_lon             23111 non-null float64
# end_state           23099 non-null object
# driver_start_lat    19621 non-null float64
# driver_start_lon    19621 non-null float64
# arrived_at          17716 non-null datetime64[ns]
# currency            23111 non-null object
# price               22713 non-null float64
# price_distance      19941 non-null float64
# price_duration      19941 non-null float64
# distance            22848 non-null float64
# duration            22848 non-null float64
# cost                21760 non-null float64
# cost_distance       18038 non-null float64
# cost_duration       18038 non-null float64
# source              22988 non-null object
# driver_score        7650 non-null float64
# rider_score         15390 non-null float64
# dtypes: datetime64[ns](3), float64(16), object(9)
# memory usage: 4.9+ MB

# %%
#cabify2010['start_at'] = pd.to_datetime(cabify2010['start_at'], format="%m/%d/%Y %H:%M:%S")
cabify2010['DayOfWeekNum'] = cabify2010['start_at'].dt.dayofweek
cabify2010['DayOfWeek'] = cabify2010['start_at'].dt.weekday_name
cabify2010['MonthDayNum'] = cabify2010['start_at'].dt.day
cabify2010['HourOfDay'] = cabify2010['start_at'].dt.hour

# %% [markdown]
# ### Alternative datetime

# %%
#converting start_at column to datetime 
#cabify2010['start_at'] =  pd.to_datetime(cabify2010['start_at'], format='%Y-%m-%d %H:%M:%S')


#extracting the Hour from start_at column and putting it into a new column named 'Hour'
cabify2010['Hour'] = cabify2010.start_at.apply(lambda x: x.hour)

#extracting the Minute from start_at column and putting it into a new column named 'Minute'
cabify2010['Minute'] = cabify2010.start_at.apply(lambda x: x.minute)

#extracting the Month from start_at column and putting it into a new column named 'Month'
cabify2010['Month'] = cabify2010.start_at.apply(lambda x: x.month)

#extracting the Day from start_at column and putting it into a new column named 'Day'
cabify2010['Day'] = cabify2010.start_at.apply(lambda x: x.day)

#extracting the Weekday from start_at column and putting it into a new column named 'WeekDay'
cabify2010['WeekDay'] = cabify2010.start_at.apply(lambda x: x.strftime('%A'))

# %%
#browse updated dataset
cabify2010.iloc[:10,:5]
# Out:
#                          journey_id                           user_id  \
# 0  23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1  dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2  dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3  dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4  85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
# 5  2254715f0f569e3173ec61f16cbb8341  56772d544fdfa589a020a1ff894a86f7
# 6  12432d83b49393bf25164673212b8295  56772d544fdfa589a020a1ff894a86f7
# 7  2e51db3a8a77aa594aa686ff19fe6036  56772d544fdfa589a020a1ff894a86f7
# 8  0234eb5f7e99d581c72052f0a868289c  0234eb5f7e99d581c72052f0a869293a
# 9  9448070ece760ea5386e5d4822121a6c  dd23cf0ef33ae44e0c0b4c756e1fe4e8
#
#                           driver_id                           taxi_id  \
# 0  583949a89a9ee17d19e3ca4f137b6b4c  b12f4f09c783e29fe0d0ea624530db56
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4  d665fb9f75ef5d9cd0fd89479380ba78  0accdd3aa5a322f4129fa20b53278c69
# 5  baacf396f773709519bbde35a5eab861  baacf396f773709519bbde35a585d91b
# 6  e1332f68e81526e498e4d845233a6d7d  e1332f68e81526e498e4d845235baf80
# 7  d665fb9f75ef5d9cd0fd89479380ba78  0accdd3aa5a322f4129fa20b53278c69
# 8  d04f1a596fe4a582f48e6eb2f9e8f617  d04f1a596fe4a582f48e6eb2f9e8cceb
# 9  406921adcca37705ef527b4246c0cfea  406921adcca37705ef527b4246c10d2c
#
#         icon
# 0  executive
# 1  executive
# 2  executive
# 3  executive
# 4  executive
# 5  executive
# 6  executive
# 7  executive
# 8  executive
# 9  executive

# %%
cabify2010.iloc[:10,5:15]
# Out:
#   start_type            start_at  start_lat  start_lon              end_at  \
# 0       asap 2010-11-16 16:44:52 -12.139835 -77.023560 2010-11-16 17:29:57
# 1       asap 2010-06-01 00:34:38 -12.138748 -76.995361 2010-06-01 00:37:39
# 2       asap 2010-05-31 05:01:24 -12.124531 -77.027802 2010-05-31 05:04:34
# 3       asap 2010-06-01 00:29:30 -12.138851 -76.995300 2010-06-01 00:32:35
# 4   reserved 2010-09-11 23:55:00 -12.089954 -76.926270 2010-09-12 01:07:02
# 5   reserved 2010-08-10 13:00:00 -12.022419 -77.106506 2010-08-10 14:26:51
# 6   reserved 2010-08-08 12:10:00 -12.089958 -76.926208 2010-08-08 12:48:02
# 7       asap 2010-05-16 03:58:59 -12.113472 -77.043854 2010-05-16 04:40:35
# 8       asap 2010-07-09 05:56:01 -12.110683 -77.002121 2010-07-09 06:37:40
# 9       asap 2010-11-22 23:42:54 -12.089696 -77.035749 2010-11-23 00:53:15
#
#      end_lat    end_lon  end_state  driver_start_lat  driver_start_lon
# 0 -12.055370 -77.041321   drop off        -12.108255        -77.027274
# 1 -12.124657 -77.028870  not found               NaN               NaN
# 2 -12.138832 -76.995300  not found               NaN               NaN
# 3 -12.124588 -77.028961  not found               NaN               NaN
# 4 -12.022232 -77.106384   drop off        -12.083116        -76.927707
# 5 -12.089802 -76.926086   drop off        -12.017068        -77.059865
# 6 -12.021523 -77.106232   drop off        -12.085091        -76.969444
# 7 -12.091087 -76.922668   drop off        -12.108290        -77.035302
# 8 -12.072996 -77.097853   drop off        -12.125842        -77.032988
# 9 -12.034499 -77.030210   drop off        -12.089820        -77.035866

# %%
cabify2010.iloc[:10,15:28]
# Out:
#            arrived_at currency   price  price_distance  price_duration  \
# 0 2010-11-16 17:02:14      PEN  3821.0          3626.0           195.0
# 1                 NaT      PEN     0.0             NaN             NaN
# 2                 NaT      PEN     0.0             NaN             NaN
# 3                 NaT      PEN     0.0             NaN             NaN
# 4 2010-09-11 23:50:00      PEN  8227.0          7665.0           562.0
# 5 2010-08-10 12:53:12      PEN  8394.0          7393.0          1001.0
# 6 2010-08-08 12:01:59      PEN  7112.0          7112.0             0.0
# 7 2010-05-16 04:06:44      PEN  5712.0          5519.0           193.0
# 8 2010-07-09 06:13:00      PEN  4680.0          4602.0            78.0
# 9 2010-11-23 00:05:24      PEN  3145.0          2580.0           565.0
#
#    distance  duration    cost  cost_distance  cost_duration   source  \
# 0   11331.0     234.0     0.0            0.0            0.0   iPhone
# 1       0.0       0.0     0.0            NaN            NaN   iPhone
# 2       0.0       0.0     0.0            NaN            NaN   iPhone
# 3       0.0       0.0     0.0            NaN            NaN   iPhone
# 4   30270.0     715.0  6173.0         5756.0          417.0   iPhone
# 5   29080.0    1201.0  5875.0         5175.0          700.0   iPhone
# 6   27230.0       0.0  5340.0         5340.0            0.0   iPhone
# 7   17247.0     232.0  4282.0         4139.0          143.0   iPhone
# 8   14380.0      94.0  3509.0         3451.0           58.0  Android
# 9    8064.0     676.0  2353.0         1935.0          418.0  Android
#
#    driver_score  rider_score
# 0           5.0          5.0
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4           4.0          5.0
# 5           NaN          4.0
# 6           5.0          5.0
# 7           5.0          5.0
# 8           0.0          4.0
# 9           5.0          5.0

# %%
cabify2010.iloc[:10,28:40]
# Out:
#    DayOfWeekNum DayOfWeek  MonthDayNum  HourOfDay  Hour  Minute  Month  Day  \
# 0             1   Tuesday           16         16    16      44     11   16
# 1             1   Tuesday            1          0     0      34      6    1
# 2             0    Monday           31          5     5       1      5   31
# 3             1   Tuesday            1          0     0      29      6    1
# 4             5  Saturday           11         23    23      55      9   11
# 5             1   Tuesday           10         13    13       0      8   10
# 6             6    Sunday            8         12    12      10      8    8
# 7             6    Sunday           16          3     3      58      5   16
# 8             4    Friday            9          5     5      56      7    9
# 9             0    Monday           22         23    23      42     11   22
#
#     WeekDay
# 0   Tuesday
# 1   Tuesday
# 2    Monday
# 3   Tuesday
# 4  Saturday
# 5   Tuesday
# 6    Sunday
# 7    Sunday
# 8    Friday
# 9    Monday

# %%
cabify_weekdays = cabify2010.pivot_table(index=['DayOfWeekNum','DayOfWeek'],
                                  values='journey_id',
                                  aggfunc='count')
cabify_weekdays.plot(kind='bar')
plt.ylabel('Total Journeys')
plt.title('Journeys by Week Day');

# %%
#group the data by Weekday and hour
summary = cabify2010.groupby(['WeekDay', 'Hour'])['start_at'].count()

# %%
#reset index
summary = summary.reset_index()
#convert to dataframe
summary = pd.DataFrame(summary)
#browse data
summary.head()
# Out:
#   WeekDay  Hour  start_at
# 0  Friday     0       179
# 1  Friday     1       119
# 2  Friday     2        81
# 3  Friday     3        98
# 4  Friday     4        58

# %%
#rename last column
summary=summary.rename(columns = {'start_at':'Counts'})

# %%
tableau_color_blind = [(0, 107, 164), (255, 128, 14), (171, 171, 171), (89, 89, 89),
             (95, 158, 209), (200, 82, 0), (137, 137, 137), (163, 200, 236),
             (255, 188, 121), (207, 207, 207)]

for i in range(len(tableau_color_blind)):  
    r, g, b = tableau_color_blind[i]  
    tableau_color_blind[i] = (r / 255., g / 255., b / 255.)

# %%
sns.set_style('whitegrid')

## set palette   
current_palette = sns.color_palette(tableau_color_blind)

ax = sns.pointplot(x="Hour", y="Counts", hue="WeekDay", data=summary, palette = current_palette,)
handles,labels = ax.get_legend_handles_labels()
#reordering legend content
handles = [handles[1], handles[5], handles[6], handles[4], handles[0], handles[2], handles[3]]
labels = [labels[1], labels[5], labels[6], labels[4], labels[0], labels[2], labels[3]]
ax.yaxis.set_major_formatter(FormatStrFormatter('%.0f'))
ax.set_xlabel('Hour', fontsize = 12)
ax.set_ylabel('Count of Cabify Pickups', fontsize = 12)
ax.set_title('Hourly Cabify Pickups By Day of the Week in Peru (Jan-X 2010)', fontsize=16)
ax.tick_params(labelsize = 8)
ax.legend(handles,labels,loc=0, title="Legend", prop={'size':8})
ax.get_legend().get_title().set_fontsize('8')
plt.show()

# %%
## groupby operation
hourly_ride_data = cabify2010.groupby(['Day','Hour','WeekDay'])['timestamp'].count()

## reset index
hourly_ride_data = hourly_ride_data.reset_index()

## rename column
hourly_ride_data = hourly_ride_data.rename(columns = {'timestamp':'ride_count'})

## ocular analysis
hourly_ride_data.head()

# %%
## groupby operation
weekday_hourly_avg = hourly_ride_data.groupby(['weekday','hour'])['ride_count'].mean()

## reset index
weekday_hourly_avg = weekday_hourly_avg.reset_index()

## rename column
weekday_hourly_avg = weekday_hourly_avg.rename(columns = {'ride_count':'average_rides'})

## sort by categorical index
weekday_hourly_avg = weekday_hourly_avg.sort_index()

## ocular analysis
weekday_hourly_avg.head()

# %%
# Cabify pickups by the month in NYC
sns.set_style('whitegrid')
ax = sns.countplot(x="Month", data=cabify2010, color="lightsteelblue")
ax.yaxis.set_major_formatter(FormatStrFormatter('%.0f'))
ax.set_xlabel('Month', fontsize = 12)
ax.set_ylabel('Count of Cabify Pickups', fontsize = 12)
ax.set_title('Cabify pickups by the Month in Peru (Jan-X 2010)', fontsize=16)
ax.tick_params(labelsize = 8)
plt.show()

# %%
cabify_monthdays = cabify2010.pivot_table(index=['MonthDayNum'],
                                  values='journey_id',
                                  aggfunc='count')
cabify_monthdays.plot(kind='bar')
plt.ylabel('Total Journeys')
plt.title('Journeys by Month Day');

# %%
# Cabify pickups by the hour in Peru
sns.set_style('whitegrid')
ax = sns.countplot(x="Hour", data=cabify2010, color="lightsteelblue")
ax.yaxis.set_major_formatter(FormatStrFormatter('%.0f'))
ax.set_xlabel('Hour of the Day', fontsize = 12)
ax.set_ylabel('Count of Cabify Pickups', fontsize = 12)
ax.set_title('Cabify pickups by the Hour in Peru (Jan-X 2010)', fontsize=16)
ax.tick_params(labelsize = 8)
plt.show()

# %%
cabify_hour = cabify2010.pivot_table(index=['HourOfDay'],
                                  values='journey_id',
                                  aggfunc='count')
cabify2010.plot(kind='barh')
plt.ylabel('Total Journeys')
plt.title('Journeys by Hour');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/marcusrb/.local/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1978         try:
# -> 1979             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1980             # If tzaware, these values represent unix timestamps, so we
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'int'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/marcusrb/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/converter.py in _convert_1d(values, unit, axis)
#     293             try:
# --> 294                 values = tools.to_datetime(values)
#     295                 if isinstance(values, Index):
#
# /home/marcusrb/.local/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#
# /home/marcusrb/.local/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     790         else:
# --> 791             result = convert_listlike(arg, box, format)
#     792     else:
#
# /home/marcusrb/.local/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     459             require_iso8601=require_iso8601,
# --> 460             allow_object=True,
#     461         )
#
# /home/marcusrb/.local/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1983         except (ValueError, TypeError):
# -> 1984             raise e
#    1985
#
# /home/marcusrb/.local/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1974             yearfirst=yearfirst,
# -> 1975             require_iso8601=require_iso8601,
#    1976         )
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ValueError: mixed datetimes and integers in passed array
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1549         try:
# -> 1550             ret = self.converter.convert(x, self.units, self)
#    1551         except Exception as e:
#
# /home/marcusrb/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/converter.py in convert(values, unit, axis)
#     258         else:
# --> 259             values = DatetimeConverter._convert_1d(values, unit, axis)
#     260         return values
#
# /home/marcusrb/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/converter.py in _convert_1d(values, unit, axis)
#     299             except Exception:
# --> 300                 values = _dt_to_float_ordinal(values)
#     301
#
# /home/marcusrb/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/converter.py in _dt_to_float_ordinal(dt)
#     245     else:
# --> 246         base = dates.date2num(dt)
#     247     return base
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/dates.py in date2num(d)
#     425             return d
# --> 426         return _to_ordinalf_np_vectorized(d)
#     427
#
# /home/marcusrb/.local/lib/python3.6/site-packages/numpy/lib/function_base.py in __call__(self, *args, **kwargs)
#    2090
# -> 2091         return self._vectorize_call(func=func, args=vargs)
#    2092
#
# /home/marcusrb/.local/lib/python3.6/site-packages/numpy/lib/function_base.py in _vectorize_call(self, func, args)
#    2166
# -> 2167             outputs = ufunc(*inputs)
#    2168
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/dates.py in _to_ordinalf(dt)
#     225
# --> 226     base = float(dt.toordinal())
#     227
#
# AttributeError: 'int' object has no attribute 'toordinal'
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# <ipython-input-29-08c16f3071bb> in <module>()
#       2                                   values='journey_id',
#       3                                   aggfunc='count')
# ----> 4 cabify2010.plot(kind='barh')
#       5 plt.ylabel('Total Journeys')
#       6 plt.title('Journeys by Hour');
#
# /home/marcusrb/.local/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# /home/marcusrb/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 62     plot_obj.generate()
#      63     plot_obj.draw()
#      64     return plot_obj.result
#
# /home/marcusrb/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     279         self._compute_plot_data()
#     280         self._setup_subplots()
# --> 281         self._make_plot()
#     282         self._add_table()
#     283         self._make_legend()
#
# /home/marcusrb/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py in _make_plot(self)
#    1393                     label=label,
#    1394                     log=self.log,
# -> 1395                     **kwds
#    1396                 )
#    1397             self._add_legend_handle(rect, label, index=i)
#
# /home/marcusrb/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py in _plot(cls, ax, x, y, w, start, log, **kwds)
#    1428     @classmethod
#    1429     def _plot(cls, ax, x, y, w, start=0, log=False, **kwds):
# -> 1430         return ax.barh(x, y, w, left=start, log=log, **kwds)
#    1431
#    1432     def _decorate_ticks(self, ax, name, ticklabels, start_edge, end_edge):
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/axes/_axes.py in barh(self, y, width, height, left, align, **kwargs)
#    2595         kwargs.setdefault('orientation', 'horizontal')
#    2596         patches = self.bar(x=left, height=height, width=width, bottom=y,
# -> 2597                            align=align, **kwargs)
#    2598         return patches
#    2599
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2361             x0 = x
#    2362             x = np.asarray(self.convert_xunits(x))
# -> 2363             width = self._convert_dx(width, x0, x, self.convert_xunits)
#    2364             if xerr is not None:
#    2365                 xerr = self._convert_dx(xerr, x0, x, self.convert_xunits)
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/axes/_axes.py in _convert_dx(dx, x0, xconv, convert)
#    2184             # if the above fails (for any reason) just fallback to what
#    2185             # we do by default and convert dx by itself.
# -> 2186             dx = convert(dx)
#    2187         return dx
#    2188
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/artist.py in convert_xunits(self, x)
#     178         if ax is None or ax.xaxis is None:
#     179             return x
# --> 180         return ax.xaxis.convert_units(x)
#     181
#     182     def convert_yunits(self, y):
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1551         except Exception as e:
#    1552             raise munits.ConversionError('Failed to convert value(s) to axis '
# -> 1553                                          f'units: {x!r}') from e
#    1554         return ret
#    1555
#
# ConversionError: Failed to convert value(s) to axis units: array([Timestamp('2010-11-16 17:29:57'), Timestamp('2010-06-01 00:37:39'),
#        Timestamp('2010-05-31 05:04:34'), ...,
#        Timestamp('2010-09-21 10:18:53'), Timestamp('2010-04-29 05:11:29'),
#        Timestamp('2010-03-16 20:02:29')], dtype=object)
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7f9a5fc54e18> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     126         for f_mgr in cls.get_all_fig_managers():
#     127             if force or f_mgr.canvas.figure.stale:
# --> 128                 f_mgr.canvas.draw_idle()
#     129
#     130 atexit.register(Gcf.destroy_all)
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1905         if not self._is_idle_drawing:
#    1906             with self._idle_draw_cntx():
# -> 1907                 self.draw(*args, **kwargs)
#    1908
#    1909     def draw_cursor(self, event):
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2605                 artists.remove(spine)
#    2606
# -> 2607         self._update_title_position(renderer)
#    2608
#    2609         if not self.axison or inframe:
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in _update_title_position(self, renderer)
#    2547                     if (ax.xaxis.get_label_position() == 'top' or
#    2548                             ax.xaxis.get_ticks_position() in choices):
# -> 2549                         bb = ax.xaxis.get_tightbbox(renderer)
#    2550                     else:
#    2551                         bb = ax.get_window_extent(renderer)
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/axis.py in get_tightbbox(self, renderer)
#    1160             return
#    1161
# -> 1162         ticks_to_draw = self._update_ticks()
#    1163
#    1164         self._update_label_position(renderer)
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/axis.py in _update_ticks(self)
#    1077         the axes.  Return the list of ticks that will be drawn.
#    1078         """
# -> 1079         major_locs = self.get_majorticklocs()
#    1080         major_labels = self.major.formatter.format_ticks(major_locs)
#    1081         major_ticks = self.get_major_ticks(len(major_locs))
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/axis.py in get_majorticklocs(self)
#    1322     def get_majorticklocs(self):
#    1323         """Get the array of major tick locations in data coordinates."""
# -> 1324         return self.major.locator()
#    1325
#    1326     def get_minorticklocs(self):
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/dates.py in __call__(self)
#    1429     def __call__(self):
#    1430         'Return the locations of the ticks'
# -> 1431         self.refresh()
#    1432         return self._locator()
#    1433
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/dates.py in refresh(self)
#    1449     def refresh(self):
#    1450         'Refresh internal information based on current limits.'
# -> 1451         dmin, dmax = self.viewlim_to_dt()
#    1452         self._locator = self.get_locator(dmin, dmax)
#    1453
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/dates.py in viewlim_to_dt(self)
#    1200                              'often happens if you pass a non-datetime '
#    1201                              'value to an axis that has datetime units'
# -> 1202                              .format(vmin))
#    1203         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#    1204
#
# ValueError: view limit minimum -36787.92046243173 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/lib/python3/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /usr/lib/python3/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     239
#     240     if 'png' in formats:
# --> 241         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     242     if 'retina' in formats or 'png2x' in formats:
#     243         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/lib/python3/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
#     124     bytes_io = BytesIO()
# --> 125     fig.canvas.print_figure(bytes_io, **kw)
#     126     data = bytes_io.getvalue()
#     127     if fmt == 'svg':
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2054                         orientation=orientation,
#    2055                         dryrun=True,
# -> 2056                         **kwargs)
#    2057                     renderer = self.figure._cachedRenderer
#    2058                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2605                 artists.remove(spine)
#    2606
# -> 2607         self._update_title_position(renderer)
#    2608
#    2609         if not self.axison or inframe:
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in _update_title_position(self, renderer)
#    2547                     if (ax.xaxis.get_label_position() == 'top' or
#    2548                             ax.xaxis.get_ticks_position() in choices):
# -> 2549                         bb = ax.xaxis.get_tightbbox(renderer)
#    2550                     else:
#    2551                         bb = ax.get_window_extent(renderer)
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/axis.py in get_tightbbox(self, renderer)
#    1160             return
#    1161
# -> 1162         ticks_to_draw = self._update_ticks()
#    1163
#    1164         self._update_label_position(renderer)
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/axis.py in _update_ticks(self)
#    1077         the axes.  Return the list of ticks that will be drawn.
#    1078         """
# -> 1079         major_locs = self.get_majorticklocs()
#    1080         major_labels = self.major.formatter.format_ticks(major_locs)
#    1081         major_ticks = self.get_major_ticks(len(major_locs))
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/axis.py in get_majorticklocs(self)
#    1322     def get_majorticklocs(self):
#    1323         """Get the array of major tick locations in data coordinates."""
# -> 1324         return self.major.locator()
#    1325
#    1326     def get_minorticklocs(self):
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/dates.py in __call__(self)
#    1429     def __call__(self):
#    1430         'Return the locations of the ticks'
# -> 1431         self.refresh()
#    1432         return self._locator()
#    1433
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/dates.py in refresh(self)
#    1449     def refresh(self):
#    1450         'Refresh internal information based on current limits.'
# -> 1451         dmin, dmax = self.viewlim_to_dt()
#    1452         self._locator = self.get_locator(dmin, dmax)
#    1453
#
# /home/marcusrb/.local/lib/python3.6/site-packages/matplotlib/dates.py in viewlim_to_dt(self)
#    1200                              'often happens if you pass a non-datetime '
#    1201                              'value to an axis that has datetime units'
# -> 1202                              .format(vmin))
#    1203         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#    1204
#
# ValueError: view limit minimum -36787.92046243173 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units

# %%
latMin = cabify2010['start_lat'].min()
latMin
# Out:
# -12.805166

# %%
latMax = cabify2010['start_lat'].max()
latMax
# Out:
# -11.889502

# %%
lonMin = cabify2010['start_lon'].min()
lonMin
# Out:
# -77.1643981933594

# %%
lonMax = cabify2010['start_lon'].max()
lonMax
# Out:
# -76.564199

# %%
fig, ax = plt.subplots(ncols=1, nrows=1,figsize=(16,12))
plt.ylim(latMin, latMax)
plt.xlim(lonMin, lonMax)
ax.scatter(cabify2010['start_lon'],cabify2010['start_lat'], s=0.02, alpha=1)

# %%
from mpl_toolkits.basemap import Basemap

west, south, east, north = lonMin, latMin, lonMax, latMax

fig = plt.figure(figsize=(14,10))
ax = fig.add_subplot(111)
m = Basemap(projection='merc', llcrnrlat=south, urcrnrlat=north,
            llcrnrlon=west, urcrnrlon=east, lat_ts=south, resolution='i')
x, y = m(cabify2010['start_lon'].values, cabify2010['start_lat'].values)
m.hexbin(x, y, gridsize=1000,
         bins='log', cmap=cm.YlOrRd_r);
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-90-38349a2be693> in <module>()
# ----> 1 from mpl_toolkits.basemap import Basemap
#       2
#       3 west, south, east, north = lonMin, latMin, lonMax, latMax
#       4
#       5 fig = plt.figure(figsize=(14,10))
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'

# %%
def heat_map(ax_loc,title_str,rides_this_hour,nsew):
    
    ## get the axis
    ax = fig.add_subplot(ax_loc)

    ## make the basemap object
    m = Basemap(projection='merc', urcrnrlat=nsew[0], llcrnrlat=nsew[1],
                urcrnrlon=nsew[2], llcrnrlon=nsew[3], lat_ts=nsew[1], resolution='f')

    ## draw the background features
    m.drawmapboundary(fill_color = 'xkcd:light blue')
    m.fillcontinents(color='xkcd:grey', zorder = 1)
    m.drawcoastlines()
    m.drawrivers()

    ## project the GPS coordinates onto the x,y representation
    x, y = m(rides_this_hour['lon'].values, rides_this_hour['lat'].values)

    ## count the instances using the hexbin method and plot the results
    m.hexbin(x, y, gridsize=1000, mincnt = 1, bins = 'log', cmap=cm.YlOrRd, zorder = 2);

    ## set the title
    ax.set_title(title_str, fontsize=24)

# %%
## set weekday for analysis
target_day = 'Monday'

## north,south,east,west lat/lon coordinates for bounding box
nsew = [40.9, 40.6, -73.8, -74.1]

## create figure
fig = plt.figure(figsize=(14,8))

## target hours
hrs = [13, 14, 21, 22, 23]

## axis subplot locations
ax_loc = [131, 132, 133] 

## title strings
title_str = ['1pm', '2pm', '9pm', '10pm', '11pm']

## plot loop
for ii in range(len(ax_loc)):

    ## get the ride data from the target hour
    rides_this_hour = cabify2010.loc[(cabify2010['WeekDay'] == target_day) & (cabify2010['Hour'] == hrs[ii])]

    ##  plot the heat map
    heat_map(ax_loc[ii],title_str[ii],rides_this_hour,nsew)
